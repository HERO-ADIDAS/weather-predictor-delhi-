# %%
import pandas as pd

# Read the CSV file, skipping the first 3 rows
df = pd.read_csv('open-meteo-28.62N77.25E218m (3).csv', skiprows=3,index_col='time')



df.head()
# Out:
#                   temperature_2m (°C)  apparent_temperature (°C)  \
# time
# 2023-09-01T00:00                 30.9                       37.1
# 2023-09-01T01:00                 30.4                       36.6
# 2023-09-01T02:00                 30.0                       36.3
# 2023-09-01T03:00                 29.7                       35.8
# 2023-09-01T04:00                 29.5                       35.6
#
#                   precipitation_probability (%)  precipitation (mm)  rain (mm)
# time
# 2023-09-01T00:00                            NaN                 0.0        0.0
# 2023-09-01T01:00                            NaN                 0.0        0.0
# 2023-09-01T02:00                            NaN                 0.0        0.0
# 2023-09-01T03:00                            NaN                 0.0        0.0
# 2023-09-01T04:00                            NaN                 0.0        0.0
